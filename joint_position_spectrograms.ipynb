# %%
import librosa
import statistics
import librosa.display
import numpy as np
import binascii
import matplotlib.pyplot as plt
from PIL import Image
from IPython import display
import scipy.signal as signal
from sklearn import svm
from sklearn import ensemble
from sklearn import neural_network
import cv2
import csv
import os
import json

# %%
positions = np.load('output/signals/6_joint_signal.npy')

# %%
plt.plot(positions[:,0])

# %%
plt.plot(positions[:,1])

# %%
f, t, z = signal.spectrogram(positions[:,0], fs=15, window='hann', nperseg=20, noverlap=15)
#print(f)
#print(t)
#print(z)
plt.pcolormesh(t, f, z)
plt.ylabel('Frequency [Hz]')
#plt.ylim([0,2500])
plt.tight_layout()
plt.xlabel('Time [sec]')
plt.show()
