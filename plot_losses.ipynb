# %%
import numpy as np
import matplotlib.pyplot as plt 
from scipy.ndimage.filters import gaussian_filter1d

# %%
linear_loss = np.load('output/linear_non_normalized_loss.npy')

# %%
plt.plot(linear_loss[::10])

# %%
bisect_left_loss = np.load('output/fc_bisect_left_loss.npy')

# %%
loss_smoothed = gaussian_filter1d(bisect_left_loss, sigma=2)
plt.plot(loss_smoothed)

# %%
bisect_right_loss = np.load('output/fc_bisect_right_loss.npy')

# %%
loss_smoothed = gaussian_filter1d(bisect_right_loss, sigma=2)
plt.plot(loss_smoothed)

# %%
conv_loss = np.load('output/conv_loss.npy')

# %%
loss_smoothed = gaussian_filter1d(conv_loss, sigma=2)
plt.plot(loss_smoothed)
