# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
linear_loss = np.load('output/linear_non_normalized_loss.npy')

# %%
plt.plot(linear_loss[:100])

# %%
loss = np.load('output/loss.npy')

# %%
plt.plot(loss[:100])
